# %% [markdown]
# # Importando pacotes e base de dados

# %%
import networkx as nx
import matplotlib.pyplot as plt
import pydot
from networkx.drawing.nx_pydot import graphviz_layout

# %% [markdown]
# ## Descrição da base de dados
# ### Download do arquivo
# http://vlado.fmf.uni-lj.si/pub/networks/data/cite/SmallW.zip
#
# ### Descrição das bases
# http://vlado.fmf.uni-lj.si/pub/networks/data/cite/default.htm

# %%
graph = nx.read_pajek('./small-world/SmallW.paj')

# %%
graph

# %% [markdown]
# # Visualizando a base de dados
# A função `draw_graph()` plota os grafos conforme uma série de parâmetros como a resolução da imagem ou o layout do grafo

# %%
def draw_graph(graph, sizex, sizey, line_width, opacity, plt_type, labels, color_node):
    # Figure size
    plt.figure(figsize=(sizex, sizey))

    # Pos
    if plt_type == 'r': 
        pos = nx.random_layout(graph) # I like this one
    if plt_type == 'c': 
        pos = nx.circular_layout(graph)
    if plt_type == 't':
        pos = graphviz_layout(graph, prog="twopi")  

    # Node options
    node_options = {"node_color": "red", "node_size": 12}

    if (color_node):
        i = 0
        color_map = []
        for node in graph:
            if i == 0:
                color_map.append('blue')
            else:
                color_map.append('red')
            i += 1
        node_options = {"node_color": color_map, "node_size": 15}
    
    # Edge options
    edge_options = {"width": line_width, "alpha": opacity, "edge_color": "black"}

    # Node label options
    node_label_options = { "font_size": 10,
                           "font_color": "green",
                           "verticalalignment": "bottom",
                           "horizontalalignment": "left"}

    # Draw nodes
    nx.draw_networkx_nodes(graph, pos, **node_options)

    # Draw edges
    nx.draw_networkx_edges(graph, pos, **edge_options)

    # Draw node labels
    if labels != None:
        nx.draw_networkx_labels(graph, pos, **node_label_options)

    plt.show()

# %% [markdown]
# ## Grafo completo das citações de artigos no layout randômico

# %%
draw_graph(graph=graph, 
           sizex=24, 
           sizey=18, 
           line_width=.05, 
           opacity=.6, 
           plt_type='r', 
           labels=True, 
           color_node=False)

# %% [markdown]
# ## Grafo completo das citações de artigos no layout circular

# %%
draw_graph(graph=graph, 
           sizex=24, 
           sizey=18, 
           line_width=.05, 
           opacity=.6, 
           plt_type='c', 
           labels=None, 
           color_node=False)

# %% [markdown]
# # Explorando o grafo

# %%
res = nx.dfs_tree(graph, 'Newman MEJ', 3)

# %%
authors_array = []

for i in res.nodes:
    authors_array.append({"node": i, "indegree": graph.in_degree(i)})
    
ordered_authors_array = sorted(authors_array, reverse=True, key=lambda x: x["indegree"])
ordered_authors_array
# Out:
# [{'node': 'Newman MEJ', 'indegree': 110},
#  {'node': 'Dorogovtsev SN', 'indegree': 74},
#  {'node': 'Albert R', 'indegree': 64},
#  {'node': 'Jespersen S', 'indegree': 50},
#  {'node': 'Zanette DH', 'indegree': 48},
#  {'node': 'Kim BJ', 'indegree': 42},
#  {'node': 'Yang XS', 'indegree': 34},
#  {'node': 'Karimipour V', 'indegree': 28},
#  {'node': 'Strogatz SH', 'indegree': 26},
#  {'node': 'Cancho RFI', 'indegree': 24},
#  {'node': 'Watts DJ', 'indegree': 24},
#  {'node': 'Davidsen J', 'indegree': 22},
#  {'node': 'Almaas E', 'indegree': 22},
#  {'node': 'Kuperman M', 'indegree': 22},
#  {'node': 'Barabasi AL', 'indegree': 22},
#  {'node': 'Manrubia SC', 'indegree': 20},
#  {'node': 'Pandit SA', 'indegree': 20},
#  {'node': 'Latora V', 'indegree': 18},
#  {'node': 'Jasch F', 'indegree': 18},
#  {'node': 'Moore C', 'indegree': 18},
#  {'node': 'Scala A', 'indegree': 16},
#  {'node': 'Lopez L', 'indegree': 16},
#  {'node': 'Blumen A', 'indegree': 16},
#  {'node': 'Elgazzar AS', 'indegree': 16},
#  {'node': 'Zekri N', 'indegree': 16},
#  {'node': 'Sanchez AD', 'indegree': 16},
#  {'node': 'Wuchty S', 'indegree': 14},
#  {'node': 'Albet R', 'indegree': 14},
#  {'node': 'Liljeros F', 'indegree': 14},
#  {'node': 'Gurtovenko AA', 'indegree': 14},
#  {'node': 'Pekalski A', 'indegree': 14},
#  {'node': 'Kulkarni RV', 'indegree': 14},
#  {'node': 'Ahmed E', 'indegree': 14},
#  {'node': 'Girvan M', 'indegree': 14},
#  {'node': 'Montoya JM', 'indegree': 12},
#  {'node': 'De Menezes MA', 'indegree': 12},
#  {'node': 'Lahtinen J', 'indegree': 12},
#  {'node': 'Ozana M', 'indegree': 12},
#  {'node': 'Hong H', 'indegree': 12},
#  {'node': 'Sen P', 'indegree': 10},
#  {'node': 'Zhu CP', 'indegree': 10},
#  {'node': 'Wang XF', 'indegree': 10},
#  {'node': 'Barthelemy M', 'indegree': 10},
#  {'node': 'Barrat A', 'indegree': 10},
#  {'node': 'Kleinfeld JS', 'indegree': 10},
#  {'node': 'Krapivsky PL', 'indegree': 10},
#  {'node': 'Bagnoli F', 'indegree': 10},
#  {'node': 'Comellas F', 'indegree': 8},
#  {'node': 'Mayer-Kress G', 'indegree': 8},
#  {'node': 'de Arcangelis L', 'indegree': 8},
#  {'node': 'Amaral LAN', 'indegree': 8},
#  {'node': 'Kogut B', 'indegree': 8},
#  {'node': 'Abramson G', 'indegree': 8},
#  {'node': 'Kullman L', 'indegree': 8},
#  {'node': 'Bjorneborn L', 'indegree': 8},
#  {'node': 'Cosenza MG', 'indegree': 6},
#  {'node': 'Herzel H', 'indegree': 6},
#  {'node': 'Marchiori M', 'indegree': 6},
#  {'node': 'Svenson P', 'indegree': 6},
#  {'node': 'Kleinberg JM', 'indegree': 6},
#  {'node': 'Tassier T', 'indegree': 6},
#  {'node': 'Wagner A', 'indegree': 6},
#  {'node': 'Moody J', 'indegree': 6},
#  {'node': 'Borgman CL', 'indegree': 6},
#  {'node': 'Kleczkowski A', 'indegree': 4},
#  {'node': 'Collins JJ', 'indegree': 4},
#  {'node': 'Sun K', 'indegree': 4},
#  {'node': 'Lubkin GB', 'indegree': 4},
#  {'node': 'Monasson R', 'indegree': 4},
#  {'node': 'Gitterman M', 'indegree': 4},
#  {'node': 'Fell DA', 'indegree': 4},
#  {'node': 'Lago-Fernandez LF', 'indegree': 4},
#  {'node': 'Janssen MA', 'indegree': 4},
#  {'node': 'Bohland JW', 'indegree': 4},
#  {'node': 'Yang T', 'indegree': 2},
#  {'node': 'Gade PM', 'indegree': 2},
#  {'node': 'Krajnc B', 'indegree': 2},
#  {'node': 'Zhang H', 'indegree': 2},
#  {'node': 'Gao Z', 'indegree': 2}]

# %%
related_authors = []

n = 5
first_n_authors = ordered_authors_array[:n]

first_n_authors
# Out:
# [{'node': 'Newman MEJ', 'indegree': 110},
#  {'node': 'Dorogovtsev SN', 'indegree': 74},
#  {'node': 'Albert R', 'indegree': 64},
#  {'node': 'Jespersen S', 'indegree': 50},
#  {'node': 'Zanette DH', 'indegree': 48}]

# %%
draw_graph(graph=res,
           sizex=14, 
           sizey=10, 
           line_width=.1, 
           opacity=1, 
           plt_type='t', 
           labels=True, 
           color_node=True)
# Out:
# /tmp/ipykernel_134924/565432254.py:11: DeprecationWarning: nx.nx_pydot.graphviz_layout depends on the pydot package, which hasknown issues and is not actively maintained. Consider usingnx.nx_agraph.graphviz_layout instead.
#
# See https://github.com/networkx/networkx/issues/5723
#   pos = graphviz_layout(graph, prog="twopi")

# %%
from serpapi import GoogleSearch

organic_results = []

for author in first_n_authors:
    params = {
      "engine": "google_scholar",
      "q": f"Small {author}",
      "api_key": "996bff3ffba949ed4bc1ab0888a8fba690309b70bbd6daaf7dab897c23b0a9a6"
    }

    search = GoogleSearch(params)
    results = search.get_dict()
    organic_results.append(results["organic_results"])

# %%
organic_results
# Out:
# [[{'position': 0,
#    'title': 'Temporal characterisation of the network of Danish cattle movements and its implication for disease control: 2000–2009',
#    'result_id': 'nsc6eYie5KQJ',
#    'link': 'https://www.sciencedirect.com/science/article/pii/S0167587713000640',
#    'snippet': '… This heterogeneity was partly attributable to the disassortative mixing pattern seen in the networks where low degree nodes had a tendency to preferentially attach to others with already …',
#    'publication_info': {'summary': 'MM Mweu, G Fournié, T Halasa, N Toft… - Preventive veterinary …, 2013 - Elsevier',
#     'authors': [{'name': 'MM Mweu',
#       'link': 'https://scholar.google.com/citations?user=az237d4AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=az237d4AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'az237d4AAAAJ'},
#      {'name': 'G Fournié',
#       'link': 'https://scholar.google.com/citations?user=GqLgepAAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=GqLgepAAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'GqLgepAAAAAJ'},
#      {'name': 'T Halasa',
#       'link': 'https://scholar.google.com/citations?user=Fv5FCCEAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=Fv5FCCEAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'Fv5FCCEAAAAJ'}]},
#    'resources': [{'title': 'researchgate.net',
#      'file_format': 'PDF',
#      'link': 'https://www.researchgate.net/profile/Marshal-Mweu/publication/260122382_Streptococcus_agalactiae_infection_in_the_population_of_Danish_dairy_cattle_herds_An_epidemiological_inquiry/links/02e7e52fa2b95e1c5d000000/Streptococcus-agalactiae-infection-in-the-population-of-Danish-dairy-cattle-herds-An-epidemiological-inquiry.pdf#page=83'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=nsc6eYie5KQJ',
#     'cited_by': {'total': 61,
#      'link': 'https://scholar.google.com/scholar?cites=11881796025896847262&as_sdt=2005&sciodt=0,5&hl=en',
#      'cites_id': '11881796025896847262',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=2005&cites=11881796025896847262&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:nsc6eYie5KQJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Newman+MEJ%27,+%27indegree%27:+110%7D&hl=en&as_sdt=0,5',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&engine=google_scholar&hl=en&q=related%3Ansc6eYie5KQJ%3Ascholar.google.com%2F',
#     'versions': {'total': 14,
#      'link': 'https://scholar.google.com/scholar?cluster=11881796025896847262&hl=en&as_sdt=0,5',
#      'cluster_id': '11881796025896847262',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&cluster=11881796025896847262&engine=google_scholar&hl=en'}}},
#   {'position': 1,
#    'title': 'Static network analysis of a pork supply chain in Northern Germany—Characterisation of the potential spread of infectious diseases via animal movements',
#    'result_id': '4HhgQlxW6EcJ',
#    'link': 'https://www.sciencedirect.com/science/article/pii/S0167587713000287',
#    'snippet': '… concerning the random removal of nodes. But by strategic … from the others by only a short distance, so they could be … (in-degree) ranged between 0 and 16 (median in-degree = 1)…',
#    'publication_info': {'summary': 'K Büttner, J Krieter, A Traulsen, I Traulsen - Preventive veterinary medicine, 2013 - Elsevier',
#     'authors': [{'name': 'K Büttner',
#       'link': 'https://scholar.google.com/citations?user=--qiw_oAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=--qiw_oAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '--qiw_oAAAAJ'},
#      {'name': 'A Traulsen',
#       'link': 'https://scholar.google.com/citations?user=jlfYejEAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=jlfYejEAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'jlfYejEAAAAJ'},
#      {'name': 'I Traulsen',
#       'link': 'https://scholar.google.com/citations?user=OwXOMoYAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=OwXOMoYAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'OwXOMoYAAAAJ'}]},
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=4HhgQlxW6EcJ',
#     'cited_by': {'total': 93,
#      'link': 'https://scholar.google.com/scholar?cites=5181486325540354272&as_sdt=2005&sciodt=0,5&hl=en',
#      'cites_id': '5181486325540354272',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=2005&cites=5181486325540354272&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:4HhgQlxW6EcJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Newman+MEJ%27,+%27indegree%27:+110%7D&hl=en&as_sdt=0,5',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&engine=google_scholar&hl=en&q=related%3A4HhgQlxW6EcJ%3Ascholar.google.com%2F',
#     'versions': {'total': 7,
#      'link': 'https://scholar.google.com/scholar?cluster=5181486325540354272&hl=en&as_sdt=0,5',
#      'cluster_id': '5181486325540354272',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&cluster=5181486325540354272&engine=google_scholar&hl=en'}}},
#   {'position': 2,
#    'title': 'A new centrality measure based on the negative and positive effects of clustering coefficient for identifying influential spreaders in complex networks',
#    'result_id': 'HTgZ7sDO0x0J',
#    'link': 'https://www.sciencedirect.com/science/article/pii/S0960077918301103',
#    'snippet': '… However, if we look at node K1, it is found that node K1 has small degree and clustering … We show the frequency of the appearance of different ranks in degree centrality, Closeness …',
#    'publication_info': {'summary': 'K Berahmand, A Bouyer, N Samadi - Chaos, Solitons & Fractals, 2018 - Elsevier',
#     'authors': [{'name': 'K Berahmand',
#       'link': 'https://scholar.google.com/citations?user=oDH68jcAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=oDH68jcAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'oDH68jcAAAAJ'},
#      {'name': 'A Bouyer',
#       'link': 'https://scholar.google.com/citations?user=RRc2H_AAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=RRc2H_AAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'RRc2H_AAAAAJ'},
#      {'name': 'N Samadi',
#       'link': 'https://scholar.google.com/citations?user=0Bnq8xAAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=0Bnq8xAAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '0Bnq8xAAAAAJ'}]},
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=HTgZ7sDO0x0J',
#     'cited_by': {'total': 56,
#      'link': 'https://scholar.google.com/scholar?cites=2149288775209531421&as_sdt=2005&sciodt=0,5&hl=en',
#      'cites_id': '2149288775209531421',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=2005&cites=2149288775209531421&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:HTgZ7sDO0x0J:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Newman+MEJ%27,+%27indegree%27:+110%7D&hl=en&as_sdt=0,5',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&engine=google_scholar&hl=en&q=related%3AHTgZ7sDO0x0J%3Ascholar.google.com%2F',
#     'versions': {'total': 4,
#      'link': 'https://scholar.google.com/scholar?cluster=2149288775209531421&hl=en&as_sdt=0,5',
#      'cluster_id': '2149288775209531421',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&cluster=2149288775209531421&engine=google_scholar&hl=en'}}},
#   {'position': 3,
#    'title': 'The structure and function of complex networks',
#    'result_id': 'uFFE_fQXprMJ',
#    'link': 'https://epubs.siam.org/doi/abs/10.1137/s003614450342480',
#    'snippet': '… call vertices or sometimes nodes, with connections between them… Watts [110] have carried out an email version of Milgram’s small-… of the fraction of pages with low in-degree might be an …',
#    'publication_info': {'summary': 'MEJ Newman - SIAM review, 2003 - SIAM',
#     'authors': [{'name': 'MEJ Newman',
#       'link': 'https://scholar.google.com/citations?user=rQ68pVwAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=rQ68pVwAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'rQ68pVwAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/cond-mat/0303516'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=uFFE_fQXprMJ',
#     'cited_by': {'total': 23629,
#      'link': 'https://scholar.google.com/scholar?cites=12945060519911641528&as_sdt=2005&sciodt=0,5&hl=en',
#      'cites_id': '12945060519911641528',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=2005&cites=12945060519911641528&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:uFFE_fQXprMJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Newman+MEJ%27,+%27indegree%27:+110%7D&hl=en&as_sdt=0,5',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&engine=google_scholar&hl=en&q=related%3AuFFE_fQXprMJ%3Ascholar.google.com%2F',
#     'versions': {'total': 114,
#      'link': 'https://scholar.google.com/scholar?cluster=12945060519911641528&hl=en&as_sdt=0,5',
#      'cluster_id': '12945060519911641528',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&cluster=12945060519911641528&engine=google_scholar&hl=en'}}},
#   {'position': 4,
#    'title': 'Chains of affection: The structure of adolescent romantic and sexual networks',
#    'result_id': '9UFSSJyuX8QJ',
#    'link': 'https://www.journals.uchicago.edu/doi/abs/10.1086/386272',
#    'snippet': '… may be smaller and denser, both structures are associated with high cyclicity and low path … 26Specifically, we generate 1,000 networks with the same number of nodes and the same …',
#    'publication_info': {'summary': 'PS Bearman, J Moody, K Stovel - American journal of …, 2004 - journals.uchicago.edu',
#     'authors': [{'name': 'PS Bearman',
#       'link': 'https://scholar.google.com/citations?user=sfaRGkUAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=sfaRGkUAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'sfaRGkUAAAAJ'},
#      {'name': 'J Moody',
#       'link': 'https://scholar.google.com/citations?user=sF0O-pIAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=sF0O-pIAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'sF0O-pIAAAAJ'},
#      {'name': 'K Stovel',
#       'link': 'https://scholar.google.com/citations?user=3-j51wIAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=3-j51wIAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '3-j51wIAAAAJ'}]},
#    'resources': [{'title': 'columbia.edu',
#      'file_format': 'PDF',
#      'link': 'https://academiccommons.columbia.edu/doi/10.7916/D8PZ5MF2/download'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=9UFSSJyuX8QJ',
#     'cited_by': {'total': 1020,
#      'link': 'https://scholar.google.com/scholar?cites=14150220540472869365&as_sdt=2005&sciodt=0,5&hl=en',
#      'cites_id': '14150220540472869365',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=2005&cites=14150220540472869365&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:9UFSSJyuX8QJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Newman+MEJ%27,+%27indegree%27:+110%7D&hl=en&as_sdt=0,5',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&engine=google_scholar&hl=en&q=related%3A9UFSSJyuX8QJ%3Ascholar.google.com%2F',
#     'versions': {'total': 33,
#      'link': 'https://scholar.google.com/scholar?cluster=14150220540472869365&hl=en&as_sdt=0,5',
#      'cluster_id': '14150220540472869365',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&cluster=14150220540472869365&engine=google_scholar&hl=en'}}},
#   {'position': 5,
#    'title': 'Detailing the co-authorship networks in degree coupling, edge weight and academic age perspective',
#    'result_id': 'ZBnpnsYV4bQJ',
#    'link': 'https://www.sciencedirect.com/science/article/pii/S096007791630220X',
#    'snippet': '… the same generic properties like small-world property (one can find a short path between most pairs of nodes) or scale-free degree distribution (the node degree distribution follows a …',
#    'publication_info': {'summary': 'İ Türker, A Çavuşoğlu - Chaos, Solitons & Fractals, 2016 - Elsevier',
#     'authors': [{'name': 'İ Türker',
#       'link': 'https://scholar.google.com/citations?user=DlnJCmEAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=DlnJCmEAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'DlnJCmEAAAAJ'}]},
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=ZBnpnsYV4bQJ',
#     'cited_by': {'total': 13,
#      'link': 'https://scholar.google.com/scholar?cites=13033722739400710500&as_sdt=2005&sciodt=0,5&hl=en',
#      'cites_id': '13033722739400710500',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=2005&cites=13033722739400710500&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:ZBnpnsYV4bQJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Newman+MEJ%27,+%27indegree%27:+110%7D&hl=en&as_sdt=0,5',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&engine=google_scholar&hl=en&q=related%3AZBnpnsYV4bQJ%3Ascholar.google.com%2F',
#     'versions': {'total': 6,
#      'link': 'https://scholar.google.com/scholar?cluster=13033722739400710500&hl=en&as_sdt=0,5',
#      'cluster_id': '13033722739400710500',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&cluster=13033722739400710500&engine=google_scholar&hl=en'}}},
#   {'position': 6,
#    'title': 'Analyzing maintainability and reliability of object-oriented software using weighted complex network',
#    'result_id': 'lbrOvxPFbbQJ',
#    'link': 'https://www.sciencedirect.com/science/article/pii/S0164121215001752',
#    'snippet': '… between node i and node z together with that of node j and node z … node z has a low in-degree. The communicational cohesion between nodes is inversely proportional to the in-degree…',
#    'publication_info': {'summary': 'CY Chong, SP Lee - Journal of Systems and Software, 2015 - Elsevier',
#     'authors': [{'name': 'CY Chong',
#       'link': 'https://scholar.google.com/citations?user=GOVDrswAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=GOVDrswAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'GOVDrswAAAAJ'}]},
#    'resources': [{'title': 'researchgate.net',
#      'file_format': 'PDF',
#      'link': 'https://www.researchgate.net/profile/Chun-Yong-Chong/publication/283352438_Analyzing_maintainability_and_reliability_of_object-oriented_software_using_weighted_complex_network/links/5d61d959299bf1f70b0aa415/Analyzing-maintainability-and-reliability-of-object-oriented-software-using-weighted-complex-network.pdf'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=lbrOvxPFbbQJ',
#     'cited_by': {'total': 67,
#      'link': 'https://scholar.google.com/scholar?cites=13001264387901536917&as_sdt=2005&sciodt=0,5&hl=en',
#      'cites_id': '13001264387901536917',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=2005&cites=13001264387901536917&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:lbrOvxPFbbQJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Newman+MEJ%27,+%27indegree%27:+110%7D&hl=en&as_sdt=0,5',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&engine=google_scholar&hl=en&q=related%3AlbrOvxPFbbQJ%3Ascholar.google.com%2F',
#     'versions': {'total': 5,
#      'link': 'https://scholar.google.com/scholar?cluster=13001264387901536917&hl=en&as_sdt=0,5',
#      'cluster_id': '13001264387901536917',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&cluster=13001264387901536917&engine=google_scholar&hl=en'}}},
#   {'position': 7,
#    'title': 'Network growth by copying',
#    'result_id': 'b7b033ODhEMJ',
#    'link': 'https://journals.aps.org/pre/abstract/10.1103/PhysRevE.71.036118',
#    'snippet': '… , encompassing a time span of 110 years 13. From these data, … of nodes with in-degree i and out-degree j in a network of N … ments, as well as Mark Newman for informing us about Ref. …',
#    'publication_info': {'summary': 'PL Krapivsky, S Redner - Physical Review E, 2005 - APS',
#     'authors': [{'name': 'PL Krapivsky',
#       'link': 'https://scholar.google.com/citations?user=IBiCgqcAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=IBiCgqcAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'IBiCgqcAAAAJ'},
#      {'name': 'S Redner',
#       'link': 'https://scholar.google.com/citations?user=9g6Z6_UAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=9g6Z6_UAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '9g6Z6_UAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/cond-mat/0410379'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=b7b033ODhEMJ',
#     'cited_by': {'total': 230,
#      'link': 'https://scholar.google.com/scholar?cites=4865158031168812655&as_sdt=2005&sciodt=0,5&hl=en',
#      'cites_id': '4865158031168812655',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=2005&cites=4865158031168812655&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:b7b033ODhEMJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Newman+MEJ%27,+%27indegree%27:+110%7D&hl=en&as_sdt=0,5',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&engine=google_scholar&hl=en&q=related%3Ab7b033ODhEMJ%3Ascholar.google.com%2F',
#     'versions': {'total': 16,
#      'link': 'https://scholar.google.com/scholar?cluster=4865158031168812655&hl=en&as_sdt=0,5',
#      'cluster_id': '4865158031168812655',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&cluster=4865158031168812655&engine=google_scholar&hl=en'}}},
#   {'position': 8,
#    'title': 'Detecting livestock production zones',
#    'result_id': 'dQqUxwGvVicJ',
#    'type': 'Html',
#    'link': 'https://www.sciencedirect.com/science/article/pii/S0167587713000044',
#    'snippet': '… .) are represented as nodes, and animal movements between the nodes are represented as … and its flexibility is achieved by sacrificing a small fraction of modularity. (For interpretation …',
#    'publication_info': {'summary': 'JHH Grisi-Filho, M Amaku, F Ferreira, RA Dias… - Preventive Veterinary …, 2013 - Elsevier',
#     'authors': [{'name': 'JHH Grisi-Filho',
#       'link': 'https://scholar.google.com/citations?user=H9qD0a0AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=H9qD0a0AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'H9qD0a0AAAAJ'},
#      {'name': 'M Amaku',
#       'link': 'https://scholar.google.com/citations?user=agiu0f0AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=agiu0f0AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'agiu0f0AAAAJ'},
#      {'name': 'F Ferreira',
#       'link': 'https://scholar.google.com/citations?user=oxCxdGgAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=oxCxdGgAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'oxCxdGgAAAAJ'},
#      {'name': 'RA Dias',
#       'link': 'https://scholar.google.com/citations?user=R5SHs2wAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=R5SHs2wAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'R5SHs2wAAAAJ'}]},
#    'resources': [{'title': 'sciencedirect.com',
#      'file_format': 'HTML',
#      'link': 'https://www.sciencedirect.com/science/article/pii/S0167587713000044'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=dQqUxwGvVicJ',
#     'html_version': 'https://www.sciencedirect.com/science/article/pii/S0167587713000044',
#     'cited_by': {'total': 27,
#      'link': 'https://scholar.google.com/scholar?cites=2834645437654502005&as_sdt=2005&sciodt=0,5&hl=en',
#      'cites_id': '2834645437654502005',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=2005&cites=2834645437654502005&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:dQqUxwGvVicJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Newman+MEJ%27,+%27indegree%27:+110%7D&hl=en&as_sdt=0,5',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&engine=google_scholar&hl=en&q=related%3AdQqUxwGvVicJ%3Ascholar.google.com%2F',
#     'versions': {'total': 9,
#      'link': 'https://scholar.google.com/scholar?cluster=2834645437654502005&hl=en&as_sdt=0,5',
#      'cluster_id': '2834645437654502005',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&cluster=2834645437654502005&engine=google_scholar&hl=en'}}},
#   {'position': 9,
#    'title': 'On the topologic structure of economic complex networks: empirical evidence from large scale payment network of Estonia',
#    'result_id': 'vezOByaT2w8J',
#    'link': 'https://www.sciencedirect.com/science/article/pii/S0960077916300091',
#    'snippet': '… out-degree k o and the in-degree k d of a node, and we define … is 40 and for the nodes is 110, meaning that each company … is low and disperse (more than 52% of the nodes have either …',
#    'publication_info': {'summary': 'SR de la Torre, J Kalda, R Kitt, J Engelbrecht - Chaos, Solitons & Fractals, 2016 - Elsevier',
#     'authors': [{'name': 'J Kalda',
#       'link': 'https://scholar.google.com/citations?user=A0sOHR0AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=A0sOHR0AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'A0sOHR0AAAAJ'},
#      {'name': 'R Kitt',
#       'link': 'https://scholar.google.com/citations?user=8vs_ALgAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=8vs_ALgAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '8vs_ALgAAAAJ'},
#      {'name': 'J Engelbrecht',
#       'link': 'https://scholar.google.com/citations?user=g1aiRz8AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=g1aiRz8AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'g1aiRz8AAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/1602.04352'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=vezOByaT2w8J',
#     'cited_by': {'total': 23,
#      'link': 'https://scholar.google.com/scholar?cites=1142668722017594557&as_sdt=2005&sciodt=0,5&hl=en',
#      'cites_id': '1142668722017594557',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=2005&cites=1142668722017594557&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:vezOByaT2w8J:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Newman+MEJ%27,+%27indegree%27:+110%7D&hl=en&as_sdt=0,5',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&engine=google_scholar&hl=en&q=related%3AvezOByaT2w8J%3Ascholar.google.com%2F',
#     'versions': {'total': 9,
#      'link': 'https://scholar.google.com/scholar?cluster=1142668722017594557&hl=en&as_sdt=0,5',
#      'cluster_id': '1142668722017594557',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C5&cluster=1142668722017594557&engine=google_scholar&hl=en'}}}],
#  [{'position': 0,
#    'title': 'Scaling properties of scale-free evolving networks: Continuous approach',
#    'result_id': 'g7sTOmzS5_4J',
#    'link': 'https://journals.aps.org/pre/abstract/10.1103/PhysRevE.63.056125',
#    'snippet': '… some particular node is proportional to a function of its in-degree, … Again, we study in-degree distributions, so these links may … The closer 0 is to 2, the smaller the value of g necessary to …',
#    'publication_info': {'summary': 'SN Dorogovtsev, JFF Mendes - Physical Review E, 2001 - APS',
#     'authors': [{'name': 'SN Dorogovtsev',
#       'link': 'https://scholar.google.com/citations?user=BeedFHMAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=BeedFHMAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'BeedFHMAAAAJ'},
#      {'name': 'JFF Mendes',
#       'link': 'https://scholar.google.com/citations?user=g0PnXHIAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=g0PnXHIAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'g0PnXHIAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/cond-mat/0012009'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=g7sTOmzS5_4J',
#     'cited_by': {'total': 344,
#      'link': 'https://scholar.google.com/scholar?cites=18367880967526529923&as_sdt=5,34&sciodt=0,34&hl=en',
#      'cites_id': '18367880967526529923',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C34&cites=18367880967526529923&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:g7sTOmzS5_4J:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Dorogovtsev+SN%27,+%27indegree%27:+74%7D&hl=en&as_sdt=0,34',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&engine=google_scholar&hl=en&q=related%3Ag7sTOmzS5_4J%3Ascholar.google.com%2F',
#     'versions': {'total': 10,
#      'link': 'https://scholar.google.com/scholar?cluster=18367880967526529923&hl=en&as_sdt=0,34',
#      'cluster_id': '18367880967526529923',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&cluster=18367880967526529923&engine=google_scholar&hl=en'}}},
#   {'position': 1,
#    'title': 'Evolution of networks',
#    'result_id': 'ZT_6Fxd2MtoJ',
#    'link': 'https://www.tandfonline.com/doi/abs/10.1080/00018730110112519',
#    'snippet': '… been studied by mathematical graph theory [74, 75, 76]. Some … graphs consisting of vertices (nodes) connected by edges (… small, so the degree distribution coincides with the in-degree …',
#    'publication_info': {'summary': 'SN Dorogovtsev, JFF Mendes - Advances in physics, 2002 - Taylor & Francis',
#     'authors': [{'name': 'SN Dorogovtsev',
#       'link': 'https://scholar.google.com/citations?user=BeedFHMAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=BeedFHMAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'BeedFHMAAAAJ'},
#      {'name': 'JFF Mendes',
#       'link': 'https://scholar.google.com/citations?user=g0PnXHIAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=g0PnXHIAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'g0PnXHIAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/cond-mat/0106144)'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=ZT_6Fxd2MtoJ',
#     'cited_by': {'total': 3951,
#      'link': 'https://scholar.google.com/scholar?cites=15722759090662424421&as_sdt=5,34&sciodt=0,34&hl=en',
#      'cites_id': '15722759090662424421',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C34&cites=15722759090662424421&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:ZT_6Fxd2MtoJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Dorogovtsev+SN%27,+%27indegree%27:+74%7D&hl=en&as_sdt=0,34',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&engine=google_scholar&hl=en&q=related%3AZT_6Fxd2MtoJ%3Ascholar.google.com%2F',
#     'versions': {'total': 26,
#      'link': 'https://scholar.google.com/scholar?cluster=15722759090662424421&hl=en&as_sdt=0,34',
#      'cluster_id': '15722759090662424421',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&cluster=15722759090662424421&engine=google_scholar&hl=en'}}},
#   {'position': 2,
#    'title': 'Wikipedias: Collaborative web-based encyclopedias as complex networks',
#    'result_id': 'guS2mODjTW4J',
#    'link': 'https://journals.aps.org/pre/abstract/10.1103/PhysRevE.74.016115',
#    'snippet': '… directed link leads out of a node of out-degree k and into a node of in-degree j, qj in, and qk … Having in mind small values of assortativity coefficient we obtained, this conclusion is very …',
#    'publication_info': {'summary': 'V Zlatić, M Božičević, H Štefančić, M Domazet - Physical Review E, 2006 - APS',
#     'authors': [{'name': 'V Zlatić',
#       'link': 'https://scholar.google.com/citations?user=9ZZJI_EAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=9ZZJI_EAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '9ZZJI_EAAAAJ'},
#      {'name': 'M Božičević',
#       'link': 'https://scholar.google.com/citations?user=PkI4BoYAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=PkI4BoYAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'PkI4BoYAAAAJ'},
#      {'name': 'H Štefančić',
#       'link': 'https://scholar.google.com/citations?user=nM6PSnoAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=nM6PSnoAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'nM6PSnoAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/physics/0602149'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=guS2mODjTW4J',
#     'cited_by': {'total': 255,
#      'link': 'https://scholar.google.com/scholar?cites=7948259471153095810&as_sdt=5,34&sciodt=0,34&hl=en',
#      'cites_id': '7948259471153095810',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C34&cites=7948259471153095810&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:guS2mODjTW4J:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Dorogovtsev+SN%27,+%27indegree%27:+74%7D&hl=en&as_sdt=0,34',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&engine=google_scholar&hl=en&q=related%3AguS2mODjTW4J%3Ascholar.google.com%2F',
#     'versions': {'total': 14,
#      'link': 'https://scholar.google.com/scholar?cluster=7948259471153095810&hl=en&as_sdt=0,34',
#      'cluster_id': '7948259471153095810',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&cluster=7948259471153095810&engine=google_scholar&hl=en'}}},
#   {'position': 3,
#    'title': 'Synchronizability of weighted aging scale-free networks',
#    'result_id': 'Q4L7yT4A24oJ',
#    'link': 'https://journals.aps.org/pre/abstract/10.1103/PhysRevE.74.046107',
#    'snippet': '… We also found that both the heterogeneity of nodes and a smaller average degree can improve … This weighting method results in that the in degree of each node in the weighted network …',
#    'publication_info': {'summary': 'Y Zou, J Zhu, G Chen - Physical Review E, 2006 - APS',
#     'authors': [{'name': 'G Chen',
#       'link': 'https://scholar.google.com/citations?user=nKPcjzcAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=nKPcjzcAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'nKPcjzcAAAAJ'}]},
#    'resources': [{'title': 'cityu.edu.hk',
#      'file_format': 'PDF',
#      'link': 'https://scholars.cityu.edu.hk/files/125348493/5220817.pdf'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=Q4L7yT4A24oJ',
#     'cited_by': {'total': 17,
#      'link': 'https://scholar.google.com/scholar?cites=10005591266810364483&as_sdt=5,34&sciodt=0,34&hl=en',
#      'cites_id': '10005591266810364483',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C34&cites=10005591266810364483&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:Q4L7yT4A24oJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Dorogovtsev+SN%27,+%27indegree%27:+74%7D&hl=en&as_sdt=0,34',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&engine=google_scholar&hl=en&q=related%3AQ4L7yT4A24oJ%3Ascholar.google.com%2F',
#     'versions': {'total': 7,
#      'link': 'https://scholar.google.com/scholar?cluster=10005591266810364483&hl=en&as_sdt=0,34',
#      'cluster_id': '10005591266810364483',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&cluster=10005591266810364483&engine=google_scholar&hl=en'}}},
#   {'position': 4,
#    'title': 'Preferential attachment in the growth of social networks: The internet encyclopedia Wikipedia',
#    'result_id': '5TDxjc7lns4J',
#    'link': 'https://journals.aps.org/pre/abstract/10.1103/PhysRevE.74.036116',
#    'snippet': '… ity that a node i with degree ki acquires a new node at time i, … the Portuguese Wikipedia dataset, small enough to be analyzed … power-law distributions of both the in degree and the out …',
#    'publication_info': {'summary': 'A Capocci, VDP Servedio, F Colaiori, LS Buriol… - Physical review E, 2006 - APS',
#     'authors': [{'name': 'A Capocci',
#       'link': 'https://scholar.google.com/citations?user=LUlRfzoAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=LUlRfzoAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'LUlRfzoAAAAJ'},
#      {'name': 'VDP Servedio',
#       'link': 'https://scholar.google.com/citations?user=Ry_acPEAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=Ry_acPEAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'Ry_acPEAAAAJ'},
#      {'name': 'F Colaiori',
#       'link': 'https://scholar.google.com/citations?user=OpVwPeEAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=OpVwPeEAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'OpVwPeEAAAAJ'},
#      {'name': 'LS Buriol',
#       'link': 'https://scholar.google.com/citations?user=5BoIwjYAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=5BoIwjYAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '5BoIwjYAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/physics/0602026'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=5TDxjc7lns4J',
#     'cited_by': {'total': 407,
#      'link': 'https://scholar.google.com/scholar?cites=14888590093440856293&as_sdt=5,34&sciodt=0,34&hl=en',
#      'cites_id': '14888590093440856293',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C34&cites=14888590093440856293&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:5TDxjc7lns4J:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Dorogovtsev+SN%27,+%27indegree%27:+74%7D&hl=en&as_sdt=0,34',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&engine=google_scholar&hl=en&q=related%3A5TDxjc7lns4J%3Ascholar.google.com%2F',
#     'versions': {'total': 24,
#      'link': 'https://scholar.google.com/scholar?cluster=14888590093440856293&hl=en&as_sdt=0,34',
#      'cluster_id': '14888590093440856293',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&cluster=14888590093440856293&engine=google_scholar&hl=en'}}},
#   {'position': 5,
#    'title': 'Network controllability is determined by the density of low in-degree and out-degree nodes',
#    'result_id': 'eA4vDFNkNnsJ',
#    'link': 'https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.113.078701',
#    'snippet': '… of nodes with in degree and out degree equal to one and two determines the number of driver nodes … Moreover, we show that random networks with minimum in degree and out degree …',
#    'publication_info': {'summary': "G Menichetti, L Dall'Asta, G Bianconi - Physical review letters, 2014 - APS",
#     'authors': [{'name': 'G Menichetti',
#       'link': 'https://scholar.google.com/citations?user=qZ457mMAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=qZ457mMAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'qZ457mMAAAAJ'},
#      {'name': "L Dall'Asta",
#       'link': 'https://scholar.google.com/citations?user=nZ8H4nsAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=nZ8H4nsAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'nZ8H4nsAAAAJ'},
#      {'name': 'G Bianconi',
#       'link': 'https://scholar.google.com/citations?user=ycQXwWgAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=ycQXwWgAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'ycQXwWgAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/1405.4365'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=eA4vDFNkNnsJ',
#     'cited_by': {'total': 135,
#      'link': 'https://scholar.google.com/scholar?cites=8878394023256985208&as_sdt=5,34&sciodt=0,34&hl=en',
#      'cites_id': '8878394023256985208',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C34&cites=8878394023256985208&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:eA4vDFNkNnsJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Dorogovtsev+SN%27,+%27indegree%27:+74%7D&hl=en&as_sdt=0,34',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&engine=google_scholar&hl=en&q=related%3AeA4vDFNkNnsJ%3Ascholar.google.com%2F',
#     'versions': {'total': 9,
#      'link': 'https://scholar.google.com/scholar?cluster=8878394023256985208&hl=en&as_sdt=0,34',
#      'cluster_id': '8878394023256985208',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&cluster=8878394023256985208&engine=google_scholar&hl=en'}}},
#   {'position': 6,
#    'title': 'Scale-free topology of e-mail networks',
#    'result_id': '1vIHlu8-qqYJ',
#    'link': 'https://journals.aps.org/pre/abstract/10.1103/PhysRevE.66.035103',
#    'snippet': '… nodes typically are underestimated, this exponent is smaller … of the in-degree i, ie a node’s number of different nodes it … very similar for all nodes and for internal nodes, respectively Fig. 3…',
#    'publication_info': {'summary': 'H Ebel, LI Mielsch, S Bornholdt - Physical review E, 2002 - APS',
#     'authors': [{'name': 'H Ebel',
#       'link': 'https://scholar.google.com/citations?user=agZDaPwAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=agZDaPwAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'agZDaPwAAAAJ'},
#      {'name': 'S Bornholdt',
#       'link': 'https://scholar.google.com/citations?user=d4MOb9wAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=d4MOb9wAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'd4MOb9wAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/cond-mat/0201476'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=1vIHlu8-qqYJ',
#     'cited_by': {'total': 1184,
#      'link': 'https://scholar.google.com/scholar?cites=12009480555072058070&as_sdt=5,34&sciodt=0,34&hl=en',
#      'cites_id': '12009480555072058070',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C34&cites=12009480555072058070&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:1vIHlu8-qqYJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Dorogovtsev+SN%27,+%27indegree%27:+74%7D&hl=en&as_sdt=0,34',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&engine=google_scholar&hl=en&q=related%3A1vIHlu8-qqYJ%3Ascholar.google.com%2F',
#     'versions': {'total': 14,
#      'link': 'https://scholar.google.com/scholar?cluster=12009480555072058070&hl=en&as_sdt=0,34',
#      'cluster_id': '12009480555072058070',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&cluster=12009480555072058070&engine=google_scholar&hl=en'}}},
#   {'position': 7,
#    'title': 'Breakdown of interdependent directed networks',
#    'result_id': 'EtyUavaDng4J',
#    'link': 'https://www.pnas.org/doi/abs/10.1073/pnas.1523412113',
#    'snippet': '… SF networks with and without in-degree and out-degree … and k out are the in-degree and out-degree of a given node, … G Bianconi, SN Dorogovtsev, Multiple percolation transitions …',
#    'publication_info': {'summary': 'X Liu, HE Stanley, J Gao - Proceedings of the National …, 2016 - National Acad Sciences',
#     'authors': [{'name': 'X Liu',
#       'link': 'https://scholar.google.com/citations?user=yU8_JtMAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=yU8_JtMAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'yU8_JtMAAAAJ'},
#      {'name': 'HE Stanley',
#       'link': 'https://scholar.google.com/citations?user=1fatN9EAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=1fatN9EAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '1fatN9EAAAAJ'},
#      {'name': 'J Gao',
#       'link': 'https://scholar.google.com/citations?user=qMcWVWgAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=qMcWVWgAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'qMcWVWgAAAAJ'}]},
#    'resources': [{'title': 'pnas.org',
#      'file_format': 'HTML',
#      'link': 'https://www.pnas.org/doi/full/10.1073/pnas.1523412113'},
#     {'title': 'Full View',
#      'link': 'https://scholar.google.com/scholar?output=instlink&q=info:EtyUavaDng4J:scholar.google.com/&hl=en&as_sdt=0,34&scillfp=15399391067995453827&oi=lle'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=EtyUavaDng4J',
#     'html_version': 'https://www.pnas.org/doi/full/10.1073/pnas.1523412113',
#     'cited_by': {'total': 122,
#      'link': 'https://scholar.google.com/scholar?cites=1053424457224608786&as_sdt=5,34&sciodt=0,34&hl=en',
#      'cites_id': '1053424457224608786',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C34&cites=1053424457224608786&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:EtyUavaDng4J:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Dorogovtsev+SN%27,+%27indegree%27:+74%7D&hl=en&as_sdt=0,34',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&engine=google_scholar&hl=en&q=related%3AEtyUavaDng4J%3Ascholar.google.com%2F',
#     'versions': {'total': 11,
#      'link': 'https://scholar.google.com/scholar?cluster=1053424457224608786&hl=en&as_sdt=0,34',
#      'cluster_id': '1053424457224608786',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&cluster=1053424457224608786&engine=google_scholar&hl=en'}}},
#   {'position': 8,
#    'title': 'Truncation of power law behavior in “scale-free” network models due to information filtering',
#    'result_id': 'ACx03GnDEmYJ',
#    'link': 'https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.88.138701',
#    'snippet': '… results for the indegree cumulative distributions for networks with S 5 3 105 nodes and no … distribution for f fixed has a sharper truncation and a smaller cutoff than for n fixed, which is …',
#    'publication_info': {'summary': 'S Mossa, M Barthelemy, HE Stanley, LAN Amaral - Physical Review Letters, 2002 - APS',
#     'authors': [{'name': 'S Mossa',
#       'link': 'https://scholar.google.com/citations?user=CnTSi3EAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=CnTSi3EAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'CnTSi3EAAAAJ'},
#      {'name': 'M Barthelemy',
#       'link': 'https://scholar.google.com/citations?user=2UTIVeIAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=2UTIVeIAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '2UTIVeIAAAAJ'},
#      {'name': 'HE Stanley',
#       'link': 'https://scholar.google.com/citations?user=1fatN9EAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=1fatN9EAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '1fatN9EAAAAJ'},
#      {'name': 'LAN Amaral',
#       'link': 'https://scholar.google.com/citations?user=Jo0G0c0AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=Jo0G0c0AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'Jo0G0c0AAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/cond-mat/0201421'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=ACx03GnDEmYJ',
#     'cited_by': {'total': 261,
#      'link': 'https://scholar.google.com/scholar?cites=7355156000887024640&as_sdt=5,34&sciodt=0,34&hl=en',
#      'cites_id': '7355156000887024640',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C34&cites=7355156000887024640&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:ACx03GnDEmYJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Dorogovtsev+SN%27,+%27indegree%27:+74%7D&hl=en&as_sdt=0,34',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&engine=google_scholar&hl=en&q=related%3AACx03GnDEmYJ%3Ascholar.google.com%2F',
#     'versions': {'total': 11,
#      'link': 'https://scholar.google.com/scholar?cluster=7355156000887024640&hl=en&as_sdt=0,34',
#      'cluster_id': '7355156000887024640',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C34&cluster=7355156000887024640&engine=google_scholar&hl=en'}}},
#   {'position': 9,
#    'title': 'Evolution of networks: From biological nets to the Internet and WWW',
#    'result_id': '81CnNxc4pYwJ',
#    'type': 'Book',
#    'link': 'https://books.google.com/books?hl=en&lr=&id=2isSDAAAQBAJ&oi=fnd&pg=PP1&dq=Small+%7B%27node%27:+%27Dorogovtsev+SN%27,+%27indegree%27:+74%7D&ots=6gqboQSsf-&sig=6rClEsaxqg9MtXrVlTAz3XIra44',
#    'snippet': '… The number of neurons in a human brain is much smaller than … perception of an individuum as a node of a complex system of … Most of the empirical data are degree (or in-degree, or out-…',
#    'publication_info': {'summary': 'SN Dorogovtsev, JFF Mendes - 2003 - books.google.com',
#     'authors': [{'name': 'SN Dorogovtsev',
# ...
#       'author_id': 'WKpjMHsAAAAJ'},
#      {'name': 'HA Makse',
#       'link': 'https://scholar.google.com/citations?user=Xa30RAUAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=Xa30RAUAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'Xa30RAUAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/1312.6335.pdf%3B'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=ElXcTIP9CLIJ',
#     'cited_by': {'total': 247,
#      'link': 'https://scholar.google.com/scholar?cites=12828782278936909074&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '12828782278936909074',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=12828782278936909074&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:ElXcTIP9CLIJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Zanette+DH%27,+%27indegree%27:+48%7D&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AElXcTIP9CLIJ%3Ascholar.google.com%2F',
#     'versions': {'total': 10,
#      'link': 'https://scholar.google.com/scholar?cluster=12828782278936909074&hl=en&as_sdt=0,33',
#      'cluster_id': '12828782278936909074',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=12828782278936909074&engine=google_scholar&hl=en'}}},
#   {'position': 3,
#    'title': 'Adaptive coevolutionary networks: a review',
#    'result_id': 'Bg2w6A9zN-cJ',
#    'link': 'https://royalsocietypublishing.org/doi/abs/10.1098/rsif.2007.1229',
#    'snippet': '… some nodes are of high degree while other nodes are of low … if every node has a high degree at certain times and a low … similar nodes often leads to strong heterogeneity in degree. …',
#    'publication_info': {'summary': 'T Gross, B Blasius - Journal of the Royal Society …, 2008 - royalsocietypublishing.org',
#     'authors': [{'name': 'T Gross',
#       'link': 'https://scholar.google.com/citations?user=eogyTQUAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=eogyTQUAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'eogyTQUAAAAJ'},
#      {'name': 'B Blasius',
#       'link': 'https://scholar.google.com/citations?user=hDRCDJwAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=hDRCDJwAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'hDRCDJwAAAAJ'}]},
#    'resources': [{'title': 'royalsocietypublishing.org',
#      'file_format': 'HTML',
#      'link': 'https://royalsocietypublishing.org/doi/full/10.1098/rsif.2007.1229'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=Bg2w6A9zN-cJ',
#     'html_version': 'https://royalsocietypublishing.org/doi/full/10.1098/rsif.2007.1229',
#     'cited_by': {'total': 1109,
#      'link': 'https://scholar.google.com/scholar?cites=16660911858645994758&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '16660911858645994758',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=16660911858645994758&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:Bg2w6A9zN-cJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Zanette+DH%27,+%27indegree%27:+48%7D&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3ABg2w6A9zN-cJ%3Ascholar.google.com%2F',
#     'versions': {'total': 19,
#      'link': 'https://scholar.google.com/scholar?cluster=16660911858645994758&hl=en&as_sdt=0,33',
#      'cluster_id': '16660911858645994758',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=16660911858645994758&engine=google_scholar&hl=en'}}},
#   {'position': 4,
#    'title': 'Dynamic model of time-dependent complex networks',
#    'result_id': '0tvY-6_VCxcJ',
#    'link': 'https://journals.aps.org/pre/abstract/10.1103/PhysRevE.82.046105',
#    'snippet': '… demonstrated that there is little continuity in degree centrality of nodes over time, even when … 2% of nodes (ie, the 20 000 nodes with the highest degree) is dramatically smaller with the …',
#    'publication_info': {'summary': 'SA Hill, D Braha - Physical Review E, 2010 - APS',
#     'authors': [{'name': 'SA Hill',
#       'link': 'https://scholar.google.com/citations?user=eoIvKywAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=eoIvKywAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'eoIvKywAAAAJ'},
#      {'name': 'D Braha',
#       'link': 'https://scholar.google.com/citations?user=qqpe1jMAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=qqpe1jMAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'qqpe1jMAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/0901.4407'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=0tvY-6_VCxcJ',
#     'cited_by': {'total': 87,
#      'link': 'https://scholar.google.com/scholar?cites=1660655839437446098&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '1660655839437446098',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=1660655839437446098&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:0tvY-6_VCxcJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Zanette+DH%27,+%27indegree%27:+48%7D&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3A0tvY-6_VCxcJ%3Ascholar.google.com%2F',
#     'versions': {'total': 12,
#      'link': 'https://scholar.google.com/scholar?cluster=1660655839437446098&hl=en&as_sdt=0,33',
#      'cluster_id': '1660655839437446098',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=1660655839437446098&engine=google_scholar&hl=en'}}},
#   {'position': 5,
#    'title': 'Rumor spreading and monitoring deployment in online social networks',
#    'result_id': 'LzYJHUugZGgJ',
#    'link': 'https://ieeexplore.ieee.org/abstract/document/8359853/',
#    'snippet': '… find the node i v who has the highest in-degree; … distribution, which means most nodes have only a few connection while the other small proportion of nodes occupy a large number of …',
#    'publication_info': {'summary': 'Q Han, F Miao, W Fan - 2017 IEEE 17th International …, 2017 - ieeexplore.ieee.org'},
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=LzYJHUugZGgJ',
#     'cited_by': {'total': 8,
#      'link': 'https://scholar.google.com/scholar?cites=7522313522085705263&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '7522313522085705263',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=7522313522085705263&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:LzYJHUugZGgJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Zanette+DH%27,+%27indegree%27:+48%7D&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3ALzYJHUugZGgJ%3Ascholar.google.com%2F'}},
#   {'position': 6,
#    'title': 'The navigability of strong ties: Small worlds, tie strength, and network topology',
#    'result_id': 'rBHY5xfXA-cJ',
#    'link': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/cplx.10053',
#    'snippet': '… edges per node and tending to form clusters or short cycles, … that are equiprobable, and differences in degree connectivity … alliances between distant rather than close blood-kin [48,49]. …',
#    'publication_info': {'summary': 'DR White, M Houseman - Complexity, 2002 - Wiley Online Library',
#     'authors': [{'name': 'DR White',
#       'link': 'https://scholar.google.com/citations?user=doBowIIAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=doBowIIAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'doBowIIAAAAJ'}]},
#    'resources': [{'title': 'wiley.com',
#      'file_format': 'PDF',
#      'link': 'https://onlinelibrary.wiley.com/doi/pdf/10.1002/cplx.10053'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=rBHY5xfXA-cJ',
#     'cited_by': {'total': 140,
#      'link': 'https://scholar.google.com/scholar?cites=16646385145365402028&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '16646385145365402028',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=16646385145365402028&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:rBHY5xfXA-cJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Zanette+DH%27,+%27indegree%27:+48%7D&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3ArBHY5xfXA-cJ%3Ascholar.google.com%2F',
#     'versions': {'total': 21,
#      'link': 'https://scholar.google.com/scholar?cluster=16646385145365402028&hl=en&as_sdt=0,33',
#      'cluster_id': '16646385145365402028',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=16646385145365402028&engine=google_scholar&hl=en'}}},
#   {'position': 7,
#    'title': 'Maximizing micro-blog influence in online promotion',
#    'result_id': 'dahLvexz4tAJ',
#    'link': 'https://www.sciencedirect.com/science/article/pii/S0957417416306157',
#    'snippet': '… of a selected node is small, node coverage (influence score) will also be small, even if the … analysis to identify the in-degree, out-degree, and centrality of the nodes. The results are …',
#    'publication_info': {'summary': 'F Li, TC Du - Expert Systems with Applications, 2017 - Elsevier',
#     'authors': [{'name': 'TC Du',
#       'link': 'https://scholar.google.com/citations?user=F0ENIf8AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=F0ENIf8AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'F0ENIf8AAAAJ'}]},
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=dahLvexz4tAJ',
#     'cited_by': {'total': 55,
#      'link': 'https://scholar.google.com/scholar?cites=15051720365250947189&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '15051720365250947189',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=15051720365250947189&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:dahLvexz4tAJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Zanette+DH%27,+%27indegree%27:+48%7D&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AdahLvexz4tAJ%3Ascholar.google.com%2F',
#     'versions': {'total': 3,
#      'link': 'https://scholar.google.com/scholar?cluster=15051720365250947189&hl=en&as_sdt=0,33',
#      'cluster_id': '15051720365250947189',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=15051720365250947189&engine=google_scholar&hl=en'}}},
#   {'position': 8,
#    'title': 'Opinion dynamics on coevolving networks',
#    'result_id': 'UsZSr-8tWlwJ',
#    'link': 'https://link.springer.com/chapter/10.1007/978-1-4614-6729-8_5',
#    'snippet': '… the voter model is the one proposed by Zanette and Gil [30, 31]… to another node chosen at random, keeping its in-degree … cover all of them in this short review. Many of these models are …',
#    'publication_info': {'summary': 'F Vazquez - Dynamics On and Of Complex Networks, Volume 2 …, 2013 - Springer',
#     'authors': [{'name': 'F Vazquez',
#       'link': 'https://scholar.google.com/citations?user=vW6mI40Rlj4C&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=vW6mI40Rlj4C&engine=google_scholar_author&hl=en',
#       'author_id': 'vW6mI40Rlj4C'}]},
#    'resources': [{'title': 'researchgate.net',
#      'file_format': 'PDF',
#      'link': 'https://www.researchgate.net/profile/Federico-Vazquez-3/publication/255961617_Opinion_Dynamics_on_Coevolving_Networks/links/02e7e520f943b7382d000000/Opinion-Dynamics-on-Coevolving-Networks.pdf'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=UsZSr-8tWlwJ',
#     'cited_by': {'total': 29,
#      'link': 'https://scholar.google.com/scholar?cites=6654681906855200338&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '6654681906855200338',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=6654681906855200338&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:UsZSr-8tWlwJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Zanette+DH%27,+%27indegree%27:+48%7D&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AUsZSr-8tWlwJ%3Ascholar.google.com%2F',
#     'versions': {'total': 4,
#      'link': 'https://scholar.google.com/scholar?cluster=6654681906855200338&hl=en&as_sdt=0,33',
#      'cluster_id': '6654681906855200338',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=6654681906855200338&engine=google_scholar&hl=en'}}},
#   {'position': 9,
#    'title': 'Demography-based adaptive network model reproduces the spatial organization of human linguistic groups',
#    'result_id': 'sE-z6B1lJqcJ',
#    'link': 'https://journals.aps.org/pre/abstract/10.1103/PhysRevE.92.062811',
#    'snippet': '… , leading to networks assortative in degree and to first-order … draw directed links between each node i and nodes at positions i ± … Zanette for their early contribution to some aspects of this …',
#    'publication_info': {'summary': 'JA Capitán, S Manrubia - Physical Review E, 2015 - APS',
#     'authors': [{'name': 'JA Capitán',
#       'link': 'https://scholar.google.com/citations?user=wzH0c00AAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=wzH0c00AAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': 'wzH0c00AAAAJ'},
#      {'name': 'S Manrubia',
#       'link': 'https://scholar.google.com/citations?user=-bFCGEwAAAAJ&hl=en&oi=sra',
#       'serpapi_scholar_link': 'https://serpapi.com/search.json?author_id=-bFCGEwAAAAJ&engine=google_scholar_author&hl=en',
#       'author_id': '-bFCGEwAAAAJ'}]},
#    'resources': [{'title': 'arxiv.org',
#      'file_format': 'PDF',
#      'link': 'https://arxiv.org/pdf/1508.04952'}],
#    'inline_links': {'serpapi_cite_link': 'https://serpapi.com/search.json?engine=google_scholar_cite&q=sE-z6B1lJqcJ',
#     'cited_by': {'total': 2,
#      'link': 'https://scholar.google.com/scholar?cites=12044425432581492656&as_sdt=5,33&sciodt=0,33&hl=en',
#      'cites_id': '12044425432581492656',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=5%2C33&cites=12044425432581492656&engine=google_scholar&hl=en'},
#     'related_pages_link': 'https://scholar.google.com/scholar?q=related:sE-z6B1lJqcJ:scholar.google.com/&scioq=Small+%7B%27node%27:+%27Zanette+DH%27,+%27indegree%27:+48%7D&hl=en&as_sdt=0,33',
#     'serpapi_related_pages_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&engine=google_scholar&hl=en&q=related%3AsE-z6B1lJqcJ%3Ascholar.google.com%2F',
#     'versions': {'total': 12,
#      'link': 'https://scholar.google.com/scholar?cluster=12044425432581492656&hl=en&as_sdt=0,33',
#      'cluster_id': '12044425432581492656',
#      'serpapi_scholar_link': 'https://serpapi.com/search.json?as_sdt=0%2C33&cluster=12044425432581492656&engine=google_scholar&hl=en'}}}]]

# %%
j = 0

print('\033[1m Suggested Aticles \033[0m\n')
for result in organic_results:
    for k in range(0, 2):
        print('\033[1m AUTHOR: \033[0m' + str(first_n_authors[j]['node']))
        print('\033[1m Title: \033[0m' + result[k]['title'])
        print('\033[1m Link: \033[0m' + result[k]['link'])
        print('\033[1m Snippet: \033[0m' + result[k]['snippet'])
        print('\n\n')
    
    j += 1
# Out:
#  Suggested Aticles
#
#  AUTHOR: Newman MEJ
#  Title: Temporal characterisation of the network of Danish cattle movements and its implication for disease control: 2000–2009
#  Link: https://www.sciencedirect.com/science/article/pii/S0167587713000640
#  Snippet: … This heterogeneity was partly attributable to the disassortative mixing pattern seen in the networks where low degree nodes had a tendency to preferentially attach to others with already …
#
#
#
#  AUTHOR: Newman MEJ
#  Title: Static network analysis of a pork supply chain in Northern Germany—Characterisation of the potential spread of infectious diseases via animal movements
#  Link: https://www.sciencedirect.com/science/article/pii/S0167587713000287
#  Snippet: … concerning the random removal of nodes. But by strategic … from the others by only a short distance, so they could be … (in-degree) ranged between 0 and 16 (median in-degree = 1)…
#
#
#
#  AUTHOR: Dorogovtsev SN
#  Title: Scaling properties of scale-free evolving networks: Continuous approach
#  Link: https://journals.aps.org/pre/abstract/10.1103/PhysRevE.63.056125
#  Snippet: … some particular node is proportional to a function of its in-degree, … Again, we study in-degree distributions, so these links may … The closer 0 is to 2, the smaller the value of g necessary to …
#
#
#
#  AUTHOR: Dorogovtsev SN
#  Title: Evolution of networks
#  Link: https://www.tandfonline.com/doi/abs/10.1080/00018730110112519
#  Snippet: … been studied by mathematical graph theory [74, 75, 76]. Some … graphs consisting of vertices (nodes) connected by edges (… small, so the degree distribution coincides with the in-degree …
#
#
#
#  AUTHOR: Albert R
#  Title: Scale-free networks in cell biology
#  Link: https://journals.biologists.com/jcs/article-abstract/118/21/4947/28519
#  Snippet: … In directed networks we distinguish the in-degree, the … ) degree, for example node O has both in-degree and out-degree 2. … This suggests that low-degree nodes tend to belong to highly …
#
#
#
#  AUTHOR: Albert R
#  Title: Statistical mechanics of complex networks
#  Link: https://journals.aps.org/rmp/abstract/10.1103/RevModPhys.74.47
#  Snippet: … with N nodes and connect every pair of nodes with probability p… there is a relatively short path between any two nodes. The … For directed networks we list separately the indegree (in) and …
#
#
#
#  AUTHOR: Jespersen S
#  Title: Dynamic model of time-dependent complex networks
#  Link: https://journals.aps.org/pre/abstract/10.1103/PhysRevE.82.046105
#  Snippet: … that there is little continuity in degree centrality of nodes over … diffusion over small-world and scale-free networks is also a … roughly constant, once we consider nodes below the top 50 …
#
#
#
#  AUTHOR: Jespersen S
#  Title: Small-world network spectra in mean-field theory
#  Link: https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.108.218701
#  Snippet: … ), ki is the degree of node i (replaced by the in-degree for directed networks), and ij is the … Spectra for networks with parameters other than N ¼ 1000 and k ¼ 50 yield qualitatively the …
#
#
#
#  AUTHOR: Zanette DH
#  Title: Organization of growing random networks
#  Link: https://journals.aps.org/pre/abstract/10.1103/PhysRevE.63.066123
#  Snippet: … , while a relatively small number of nodes garner a large … measured for the web graph 48,49 and for social networks 23. … also reduces the number of nodes with in-degree zero. For …
#
#
#
#  AUTHOR: Zanette DH
#  Title: Breaking news dissemination in the media via propagation behavior based on complex network theory
#  Link: https://www.sciencedirect.com/science/article/pii/S0378437116002120
#  Snippet: … To calculate the small world quotient Q , we produced 50 times a … via nodes with high in-degree and weighted in-degree, and we can control the information spreading through nodes …

# %%
import json

# %%
file_path = "output.json"

# Write the dictionary to a JSON file
with open(file_path, "w") as json_file:
    json.dump(organic_results, json_file, indent=4)

# %%
# list(graph.out_edges('Gurtovenko AA'))
# graph.out_degree('Gurtovenko AA')
# list(graph.neighbors('Gurtovenko AA'))
# nx.is_empty(graph)

def draw_graph(graph, sizex, sizey, line_width, opacity, plt_type, labels, color_node):
    # Figure size
    plt.figure(figsize=(sizex, sizey))

    # Pos
    # pos = nx.kamada_kawai_layout(graph)
    # pos = nx.spring_layout(graph)
    if plt_type == 'r': 
        pos = nx.random_layout(graph) # I like this one
    if plt_type == 'c': 
        pos = nx.circular_layout(graph)
    if plt_type == 't':
        pos = graphviz_layout(graph, prog="twopi")  
#         pos = graphviz_layout(graph, prog="dot")  

    # pos = nx.bipartite_layout(graph, 1) # Does not work yet
    # pos = nx.shell_layout(graph)
    # pos = nx.spectral_layout(graph)
    # pos = nx.spiral_layout(graph)
    # pos = nx.multipartite_layout(graph)

    # Node options
    node_options = {"node_color": "red", "node_size": 12}

    if (color_node):
        i = 0
        color_map = []
        for node in graph:
            if i == 0:
                color_map.append('blue')
            else:
                color_map.append('red')
            i += 1
        node_options = {"node_color": color_map, "node_size": 15}
    
    # Edge options
    edge_options = {"width": line_width, "alpha": opacity, "edge_color": "black"}

    # Node label options
    node_label_options = { "font_size": 10,
                           "font_color": "green",
                           "verticalalignment": "bottom",
                           "horizontalalignment": "left"}

    # Edge label options
    # edge_label_options = { "font_size": 5,
    #                        "font_color": "green",
    #                        "verticalalignment": "bottom",
    #                        "horizontalalignment": "left"}

    # Draw nodes
    nx.draw_networkx_nodes(graph, pos, **node_options)

    # Draw edges
    nx.draw_networkx_edges(graph, pos, **edge_options)

    if labels != None:
        # Draw node labels
        nx.draw_networkx_labels(graph, pos, **node_label_options)

    # Draw edge labels
    # nx.draw_networkx_edge_labels(graph, pos, **edge_label_options)

    plt.show()

# %% [markdown]
# # Tips to draw large graphs
# - Set figure size using `plt.figure(figsize=(12, 10)` from *matplotlib.pyplot*
#
# - Set `pos = nx.draw_kamada_kawai(graph)`
#
# - Set how nodes should appear with dictionary. I can be called `node_options`. This will be passed to the *networkx* function `nx.draw_networkx_nodes`
#
# - Set how your edges should appear with `edge_options`. It will be passed to `nx.draw_networkx_edges`
#
# - Call the `plt.show()` function from *matplotlib.pyplot*
